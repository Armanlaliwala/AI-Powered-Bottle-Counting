# %% [markdown]
# # This code is detecting the bottle using yolo - coco - dataset - class 39

# %%
import cv2
from ultralytics import YOLO

# Load a COCO-pretrained YOLO model (replace 'yolo11n.pt' with a valid YOLO model if necessary)
model = YOLO("yolo11n.pt")

# Load the video
video_path = 'oil-bottle.mp4'
cap = cv2.VideoCapture(video_path)

# Check if the video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Output video writer
output_path = 'output_bottle_detection.mp4'
out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

print("Processing video...")

# Process video frame by frame
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO detection on the frame
    results = model.predict(frame, conf=0.25)  # Adjust confidence threshold if needed

    # Filter detections for bottles (COCO class 39)
    bottle_detections = [det for det in results[0].boxes if int(det.cls) == 39]

    # Draw bounding boxes for detected bottles
    for det in bottle_detections:
        x1, y1, x2, y2 = map(int, det.xyxy[0])
        confidence = det.conf[0]
        label = f"Bottle {confidence:.2f}"

        # Draw rectangle and label on the frame
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the frame with detections
    cv2.imshow('Bottle Detection', frame)

    # Write the annotated frame to the output video
    out.write(frame)

    # Press 'q' to stop the video early
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Detection completed. Output saved to '{output_path}'")
# Out:
# Processing video...
#
# 0: 384x640 2 bottles, 353.4ms
# Speed: 14.9ms preprocess, 353.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 bottles, 1 cup, 248.2ms
# Speed: 11.4ms preprocess, 248.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 1 cup, 269.5ms
# Speed: 10.2ms preprocess, 269.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 263.8ms
# Speed: 8.0ms preprocess, 263.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 498.6ms
# Speed: 11.5ms preprocess, 498.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 bottles, 256.6ms
# Speed: 11.0ms preprocess, 256.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 240.4ms
# Speed: 11.0ms preprocess, 240.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 261.3ms
# Speed: 11.4ms preprocess, 261.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire hydrant, 2 bottles, 241.5ms
# Speed: 13.2ms preprocess, 241.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 235.6ms
# Speed: 9.0ms preprocess, 235.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 242.2ms
# Speed: 8.0ms preprocess, 242.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 vase, 218.7ms
# Speed: 11.0ms preprocess, 218.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 216.5ms
# Speed: 60.1ms preprocess, 216.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 219.5ms
# Speed: 14.0ms preprocess, 219.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 216.0ms
# Speed: 11.0ms preprocess, 216.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 501.7ms
# Speed: 11.2ms preprocess, 501.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 1 vase, 228.3ms
# Speed: 10.0ms preprocess, 228.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 222.9ms
# Speed: 10.0ms preprocess, 222.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 1 vase, 235.3ms
# Speed: 8.1ms preprocess, 235.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 2 vases, 224.0ms
# Speed: 10.0ms preprocess, 224.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 219.7ms
# Speed: 13.0ms preprocess, 219.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 222.8ms
# Speed: 8.0ms preprocess, 222.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 372.2ms
# Speed: 12.0ms preprocess, 372.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 223.1ms
# Speed: 9.0ms preprocess, 223.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 228.0ms
# Speed: 8.0ms preprocess, 228.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 232.4ms
# Speed: 8.0ms preprocess, 232.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 1 vase, 222.0ms
# Speed: 11.0ms preprocess, 222.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 212.4ms
# Speed: 13.5ms preprocess, 212.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 219.8ms
# Speed: 11.0ms preprocess, 219.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 1 vase, 225.5ms
# Speed: 11.0ms preprocess, 225.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 241.0ms
# Speed: 8.0ms preprocess, 241.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 219.6ms
# Speed: 10.0ms preprocess, 219.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 1 vase, 235.9ms
# Speed: 9.0ms preprocess, 235.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 2 vases, 227.2ms
# Speed: 11.5ms preprocess, 227.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 227.1ms
# Speed: 9.0ms preprocess, 227.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 221.8ms
# Speed: 9.2ms preprocess, 221.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 220.5ms
# Speed: 10.0ms preprocess, 220.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 223.6ms
# Speed: 11.0ms preprocess, 223.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 217.7ms
# Speed: 11.0ms preprocess, 217.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 216.5ms
# Speed: 11.0ms preprocess, 216.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 236.2ms
# Speed: 8.0ms preprocess, 236.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 272.7ms
# Speed: 8.4ms preprocess, 272.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 560.1ms
# Speed: 25.1ms preprocess, 560.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 218.0ms
# Speed: 12.0ms preprocess, 218.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 219.1ms
# Speed: 9.0ms preprocess, 219.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 209.2ms
# Speed: 11.4ms preprocess, 209.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 226.8ms
# Speed: 13.0ms preprocess, 226.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 209.6ms
# Speed: 9.0ms preprocess, 209.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 2 vases, 210.0ms
# Speed: 11.0ms preprocess, 210.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 200.8ms
# Speed: 10.0ms preprocess, 200.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire hydrant, 2 bottles, 211.5ms
# Speed: 9.0ms preprocess, 211.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 208.9ms
# Speed: 10.8ms preprocess, 208.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 211.1ms
# Speed: 12.2ms preprocess, 211.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 208.3ms
# Speed: 8.4ms preprocess, 208.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 218.3ms
# Speed: 9.0ms preprocess, 218.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 217.1ms
# Speed: 9.0ms preprocess, 217.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 207.3ms
# Speed: 9.4ms preprocess, 207.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 206.3ms
# Speed: 11.2ms preprocess, 206.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 213.0ms
# Speed: 55.8ms preprocess, 213.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 215.1ms
# Speed: 9.0ms preprocess, 215.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 206.0ms
# Speed: 10.0ms preprocess, 206.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 237.0ms
# Speed: 9.0ms preprocess, 237.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 1 vase, 342.7ms
# Speed: 31.2ms preprocess, 342.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 3 vases, 216.4ms
# Speed: 8.0ms preprocess, 216.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 2 vases, 230.7ms
# Speed: 10.0ms preprocess, 230.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 227.7ms
# Speed: 15.1ms preprocess, 227.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 85.7ms
# Speed: 3.0ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 90.3ms
# Speed: 2.4ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 87.7ms
# Speed: 2.1ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 117.9ms
# Speed: 3.0ms preprocess, 117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 112.4ms
# Speed: 2.0ms preprocess, 112.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Detection completed. Output saved to 'output_bottle_detection.mp4'
